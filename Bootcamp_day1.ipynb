# %% [markdown]
# <a href="https://colab.research.google.com/github/arzuunr/bootcamp_veri_analizi/blob/main/Bootcamp_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns #Data visualization library based on matplotlib statistics graphics
import datetime as date
#import pyodbc as pdbc #Used for connecting ODBC (Open Database Connectivity) databases through an interface. This simple to use package provides generic methods for accessing and interacting with various database platforms

# %%
data_churn=pd.read_csv("Customer_churn.csv")
data_gender=pd.read_csv("Customer_gender.csv")
data_churn
# Out:
#           ID  RowNumber  CustomerId    Surname  CreditScore Geography   Age  \
# 0          0          1  15634602.0   Hargrave        619.0    France  42.0
# 1          1          2  15647311.0       Hill        608.0     Spain  41.0
# 2          2          3  15619304.0       Onio        502.0    France  42.0
# 3          3          4  15701354.0       Boni        699.0    France  39.0
# 4          4          5  15737888.0   Mitchell        850.0     Spain  43.0
# ...      ...        ...         ...        ...          ...       ...   ...
# 10002  10002       9996  15606229.0   Obijiaku        771.0    France  39.0
# 10003  10003       9997  15569892.0  Johnstone        516.0    France  35.0
# 10004  10004       9998  15584532.0        Liu        709.0    France  36.0
# 10005  10005       9999  15682355.0  Sabbatini        772.0   Germany  42.0
# 10006  10006      10000  15628319.0     Walker        792.0    France  28.0
#
# ...

# %%
data_gender.head()
# Out:
#    ID  CustomerId  Gender
# 0   0  15634602.0  Female
# 1   1  15647311.0  Female
# 2   2  15619304.0  Female
# 3   3  15701354.0  Female
# 4   4  15737888.0  Female

# %%
data_churn.head()
# Out:
#    ID  RowNumber  CustomerId   Surname  CreditScore Geography   Age  Tenure  \
# 0   0          1  15634602.0  Hargrave        619.0    France  42.0     2.0
# 1   1          2  15647311.0      Hill        608.0     Spain  41.0     1.0
# 2   2          3  15619304.0      Onio        502.0    France  42.0     8.0
# 3   3          4  15701354.0      Boni        699.0    France  39.0     1.0
# 4   4          5  15737888.0  Mitchell        850.0     Spain  43.0     2.0
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00            1.0        1.0             1.0        101348.88
# 1   83807.86            1.0        0.0             1.0        112542.58
# 2  159660.80            3.0        1.0             0.0        113931.57
# 3       0.00            2.0        0.0             0.0         93826.63
# 4  125510.82            1.0        1.0             1.0         79084.10
#
#    Exited
# 0     1.0
# 1     0.0
# 2     1.0
# 3     0.0
# 4     0.0

# %%
data_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10007 entries, 0 to 10006
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               10007 non-null  int64
#  1   RowNumber        10007 non-null  int64
#  2   CustomerId       10004 non-null  float64
#  3   Surname          10004 non-null  object
#  4   CreditScore      10004 non-null  float64
#  5   Geography        10004 non-null  object
#  6   Age              10004 non-null  float64
#  7   Tenure           10004 non-null  float64
#  8   Balance          10004 non-null  float64
#  9   NumOfProducts    10004 non-null  float64
#  10  HasCrCard        10004 non-null  float64
#  11  IsActiveMember   10004 non-null  float64
#  12  EstimatedSalary  10004 non-null  float64
#  13  Exited           10004 non-null  float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
data_churn.dtypes #i couldnt do with dtypes()
# Out:
# ID                   int64
# RowNumber            int64
# CustomerId         float64
# Surname             object
# CreditScore        float64
# Geography           object
# Age                float64
# Tenure             float64
# Balance            float64
# NumOfProducts      float64
# HasCrCard          float64
# IsActiveMember     float64
# EstimatedSalary    float64
# Exited             float64
# dtype: object

# %%
data_churn[["CustomerId", "Surname", "Age"]]
# Out:
#        CustomerId    Surname   Age
# 0      15634602.0   Hargrave  42.0
# 1      15647311.0       Hill  41.0
# 2      15619304.0       Onio  42.0
# 3      15701354.0       Boni  39.0
# 4      15737888.0   Mitchell  43.0
# ...           ...        ...   ...
# 10002  15606229.0   Obijiaku  39.0
# 10003  15569892.0  Johnstone  35.0
# 10004  15584532.0        Liu  36.0
# 10005  15682355.0  Sabbatini  42.0
# 10006  15628319.0     Walker  28.0
#
# [10007 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['CustomerId'].plot(kind='hist', bins=20, title='CustomerId')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data_churn[0:5]
# Out:
#    ID  RowNumber  CustomerId   Surname  CreditScore Geography   Age  Tenure  \
# 0   0          1  15634602.0  Hargrave        619.0    France  42.0     2.0
# 1   1          2  15647311.0      Hill        608.0     Spain  41.0     1.0
# 2   2          3  15619304.0      Onio        502.0    France  42.0     8.0
# 3   3          4  15701354.0      Boni        699.0    France  39.0     1.0
# 4   4          5  15737888.0  Mitchell        850.0     Spain  43.0     2.0
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00            1.0        1.0             1.0        101348.88
# 1   83807.86            1.0        0.0             1.0        112542.58
# 2  159660.80            3.0        1.0             0.0        113931.57
# 3       0.00            2.0        0.0             0.0         93826.63
# 4  125510.82            1.0        1.0             1.0         79084.10
#
#    Exited
# 0     1.0
# 1     0.0
# 2     1.0
# 3     0.0
# 4     0.0

# %%
data_churn.describe().T
# Out:
#                    count          mean           std          min  \
# ID               10007.0  5.003000e+03   2888.916406         0.00
# RowNumber        10007.0  4.997011e+03   2888.897063         1.00
# CustomerId       10004.0  1.569090e+07  71921.021426  15565701.00
# CreditScore      10004.0  6.504141e+02     96.741372       350.00
# Age              10004.0  3.891593e+01     10.480824        18.00
# Tenure           10004.0  5.017393e+00      2.893818         0.00
# Balance          10004.0  7.644223e+04  62405.979590         0.00
# NumOfProducts    10004.0  1.530488e+00      0.581609         1.00
# HasCrCard        10004.0  7.057177e-01      0.455742         0.00
# IsActiveMember   10004.0  5.147941e-01      0.499806         0.00
# EstimatedSalary  10004.0  1.000451e+05  57529.442494        11.58
# Exited           10004.0  2.017193e-01      0.430624       -15.00
#
#                          25%           50%           75%          max
# ...

# %%
data_churn.T
# Out:
#                       0           1           2           3           4      \
# ID                        0           1           2           3           4
# RowNumber                 1           2           3           4           5
# CustomerId       15634602.0  15647311.0  15619304.0  15701354.0  15737888.0
# Surname            Hargrave        Hill        Onio        Boni    Mitchell
# CreditScore           619.0       608.0       502.0       699.0       850.0
# Geography            France       Spain      France      France       Spain
# Age                    42.0        41.0        42.0        39.0        43.0
# Tenure                  2.0         1.0         8.0         1.0         2.0
# Balance                 0.0    83807.86    159660.8         0.0   125510.82
# NumOfProducts           1.0         1.0         3.0         2.0         1.0
# HasCrCard               1.0         0.0         1.0         0.0         1.0
# ...

# %%
data_churn.iloc[:,0:5]
# Out:
#           ID  RowNumber  CustomerId    Surname  CreditScore
# 0          0          1  15634602.0   Hargrave        619.0
# 1          1          2  15647311.0       Hill        608.0
# 2          2          3  15619304.0       Onio        502.0
# 3          3          4  15701354.0       Boni        699.0
# 4          4          5  15737888.0   Mitchell        850.0
# ...      ...        ...         ...        ...          ...
# 10002  10002       9996  15606229.0   Obijiaku        771.0
# 10003  10003       9997  15569892.0  Johnstone        516.0
# 10004  10004       9998  15584532.0        Liu        709.0
# 10005  10005       9999  15682355.0  Sabbatini        772.0
# 10006  10006      10000  15628319.0     Walker        792.0
#
# [10007 rows x 5 columns]

# %%
data_churn[['CreditScore','Geography','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary','Exited']].describe().T
# Out:
#                    count           mean           std     min       25%  \
# CreditScore      10004.0     650.414134     96.741372  350.00    584.00
# Age              10004.0      38.915934     10.480824   18.00     32.00
# Tenure           10004.0       5.017393      2.893818    0.00      3.00
# Balance          10004.0   76442.229374  62405.979590    0.00      0.00
# NumOfProducts    10004.0       1.530488      0.581609    1.00      1.00
# HasCrCard        10004.0       0.705718      0.455742    0.00      0.00
# IsActiveMember   10004.0       0.514794      0.499806    0.00      0.00
# EstimatedSalary  10004.0  100045.078304  57529.442494   11.58  50895.31
# Exited           10004.0       0.201719      0.430624  -15.00      0.00
#
#                         50%          75%        max
# CreditScore         652.000     717.2500     850.00
# Age                  37.000      44.0000      92.00
# Tenure                5.000       8.0000      10.00
# ...

# %%
a1=data_churn.shape
a1
# Out:
# (10007, 14)

# %%
data_churn.isna()
# Out:
#           ID  RowNumber  CustomerId  Surname  CreditScore  Geography    Age  \
# 0      False      False       False    False        False      False  False
# 1      False      False       False    False        False      False  False
# 2      False      False       False    False        False      False  False
# 3      False      False       False    False        False      False  False
# 4      False      False       False    False        False      False  False
# ...      ...        ...         ...      ...          ...        ...    ...
# 10002  False      False       False    False        False      False  False
# 10003  False      False       False    False        False      False  False
# 10004  False      False       False    False        False      False  False
# 10005  False      False       False    False        False      False  False
# 10006  False      False       False    False        False      False  False
#
# ...

# %%
data_churn.isna().sum()
# Out:
# ID                 0
# RowNumber          0
# CustomerId         3
# Surname            3
# CreditScore        3
# Geography          3
# Age                3
# Tenure             3
# Balance            3
# NumOfProducts      3
# HasCrCard          3
# IsActiveMember     3
# EstimatedSalary    3
# Exited             3
# dtype: int64

# %%
data_gender.isna().sum()
# Out:
# ID            0
# CustomerId    3
# Gender        3
# dtype: int64

# %%
data_churn[data_churn['Age'].isna() == True]
# Out:
#       ID  RowNumber  CustomerId Surname  CreditScore Geography  Age  Tenure  \
# 236  236        230         NaN     NaN          NaN       NaN  NaN     NaN
# 237  237        231         NaN     NaN          NaN       NaN  NaN     NaN
# 238  238        232         NaN     NaN          NaN       NaN  NaN     NaN
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 236      NaN            NaN        NaN             NaN              NaN
# 237      NaN            NaN        NaN             NaN              NaN
# 238      NaN            NaN        NaN             NaN              NaN
#
#      Exited
# 236     NaN
# 237     NaN
# 238     NaN

# %%
data_gender[data_gender['Gender'].isna() == True]
# Out:
#       ID  CustomerId Gender
# 236  236         NaN    NaN
# 237  237         NaN    NaN
# 238  238         NaN    NaN

# %%
data_churn['CustomerId'].duplicated().sum()
# Out:
# np.int64(9)

# %%
data_gender["CustomerId"].duplicated().sum()
# Out:
# np.int64(606)

# %%
data_churn[data_churn['CustomerId'].duplicated() == True]
# Out:
#       ID  RowNumber  CustomerId Surname  CreditScore Geography   Age  Tenure  \
# 13    13         13  15632264.0     Kay        476.0    France  34.0    10.0
# 14    14         13  15632264.0     Kay        476.0    France  34.0    10.0
# 15    15         13  15632264.0     Kay        476.0    France  34.0    10.0
# 16    16         13  15632264.0     Kay        476.0    France  34.0    10.0
# 17    17         13  15632264.0     Kay        476.0    France  34.0    10.0
# 18    18         13  15632264.0     Kay        476.0    France  34.0    10.0
# 19    19         13  15632264.0     Kay        476.0    France  34.0    10.0
# 237  237        231         NaN     NaN          NaN       NaN   NaN     NaN
# 238  238        232         NaN     NaN          NaN       NaN   NaN     NaN
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 13       0.0            2.0        1.0             0.0         26260.98
# ...

# %%
data_churn[data_churn['CustomerId'].duplicated() == True]['CustomerId'].unique()
# Out:
# array([15632264.,       nan])

# %%
data_churn.iloc[1:4,4:]
# Out:
#    CreditScore Geography   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 1        608.0     Spain  41.0     1.0   83807.86            1.0        0.0
# 2        502.0    France  42.0     8.0  159660.80            3.0        1.0
# 3        699.0    France  39.0     1.0       0.00            2.0        0.0
#
#    IsActiveMember  EstimatedSalary  Exited
# 1             1.0        112542.58     0.0
# 2             0.0        113931.57     1.0
# 3             0.0         93826.63     0.0

# %%
data_churn.iloc[[236,237], :]
# Out:
#       ID  RowNumber  CustomerId Surname  CreditScore Geography  Age  Tenure  \
# 236  236        230         NaN     NaN          NaN       NaN  NaN     NaN
# 237  237        231         NaN     NaN          NaN       NaN  NaN     NaN
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 236      NaN            NaN        NaN             NaN              NaN
# 237      NaN            NaN        NaN             NaN              NaN
#
#      Exited
# 236     NaN
# 237     NaN

# %%
data_churn.loc[1:3, 'Surname']
# Out:
# 1    Hill
# 2    Onio
# 3    Boni
# Name: Surname, dtype: object

# %%
print(data_churn.loc[data_churn['Age'] > 55][['CustomerId','Surname']].head())

print('--------------------------------------------------------------------------------')

print('Kişi sayısı: ',len(data_churn.loc[data_churn['Age'] > 55]))
# Out:
#     CustomerId  Surname
# 23  15737452.0    Romeo
# 49  15687946.0  Osborne
# 51  15684171.0  Bianchi
# 65  15623944.0    T'ien
# 70  15751208.0  Pirozzi
# --------------------------------------------------------------------------------
# Kişi sayısı:  799

# %%
data_churn.groupby('Exited').size()
# Out:
# Exited
# -15.0       1
# -1.0        2
#  0.0     7966
#  1.0     2035
# dtype: int64

# %%
data_churn.groupby('Geography').size()
# Out:
# Geography
# France     5019
# Germany    2508
# Spain      2477
# dtype: int64
